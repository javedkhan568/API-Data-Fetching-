# %%
import pandas as pd 
import requests

# %%
url = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=c19efe31d5d02224c8eae1934a0b021f&language=en-US&page=1")

# %%
url.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/v5CEt88iDsuoMaW1Q5Msu9UZdEt.jpg',
#   'genre_ids': [10749, 18],
#   'id': 730154,
#   'original_language': 'ja',
#   'original_title': 'きみの瞳が問いかけている',
#   'overview': "A tragic accident lead to Kaori's blindness, but she clings to life and the smaller pleasures it can still afford her. She meets Rui and begins to talk to him. Rui was once a promising kickboxer, but something happened in his past. Kaori's smile brings out a change in Rui. However, the two are connected in more than one way. Rui attempts to do what is right.",
#   'popularity': 12.649,
#   'poster_path': '/cVn8E3Fxbi8HzYYtaSfsblYC4gl.jpg',
#   'release_date': '2020-10-23',
#   'title': 'Your Eyes Tell',
#   'video': False,
#   'vote_average': 8.8,
#   'vote_count': 224},
#  {'adult': False,
#   'backdrop_path': '/5hNcsnMkwU2LknLoru73c76el3z.jpg',
#   'genre_ids': [35, 18, 10749],
#   'id': 19404,
#   'original_language': 'hi',
# ...

# %%
movie_rating=pd.DataFrame(response.json()['results'])[['id', 'title','overview','popularity','original_language','vote_average']]

# %%
movie_rating
# Out:
#         id                                          title  \
# 0   730154                                 Your Eyes Tell
# 1    19404                    Dilwale Dulhania Le Jayenge
# 2      278                       The Shawshank Redemption
# 3      238                                  The Godfather
# 4   724089                      Gabriel's Inferno Part II
# 5      424                               Schindler's List
# 6      240                         The Godfather: Part II
# 7   696374                              Gabriel's Inferno
# 8   761053                     Gabriel's Inferno Part III
# 9   372058                                     Your Name.
# 10  255709                                           Hope
# 11     129                                  Spirited Away
# 12  632632                                          Given
# 13  496243                                       Parasite
# 14  283566         Evangelion: 3.0+1.0 Thrice Upon a Time
# ...

# %%
movie_rating.shape
# Out:
# (20, 6)

# %%
# creating Empty dataframe 
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range (1,429):
    url = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=c19efe31d5d02224c8eae1934a0b021f&language=en-US&page={}".format(i))  
    mov_df=pd.DataFrame(response.json()['results'])[['id', 'title','overview','popularity','original_language','vote_average']] 
    df=df.append(mov_df,ignore_index=True)

# %%
df
# Out:
#           id                                          title  \
# 0     730154                                 Your Eyes Tell
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        278                       The Shawshank Redemption
# 3        238                                  The Godfather
# 4     724089                      Gabriel's Inferno Part II
# ...      ...                                            ...
# 8555     389                                   12 Angry Men
# 8556     497                                 The Green Mile
# 8557     155                                The Dark Knight
# 8558     680                                   Pulp Fiction
# 8559     122  The Lord of the Rings: The Return of the King
#
#                                                overview  popularity  \
# 0     A tragic accident lead to Kaori's blindness, b...      12.649
# 1     Raj is a rich, carefree, happy-go-lucky second...      32.973
# ...

# %%
df.shape
# Out:
# (8560, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8560 entries, 0 to 8559
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 8560 non-null   int64
#  1   title              8560 non-null   object
#  2   overview           8560 non-null   object
#  3   popularity         8560 non-null   float64
#  4   original_language  8560 non-null   object
#  5   vote_average       8560 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 401.4+ KB

# %%
df.sample(10)
# Out:
#           id                                          title  \
# 6249  372058                                     Your Name.
# 7231     129                                  Spirited Away
# 3312  632632                                          Given
# 3099     122  The Lord of the Rings: The Return of the King
# 3552  632632                                          Given
# 7227  696374                              Gabriel's Inferno
# 7296     497                                 The Green Mile
# 2811     129                                  Spirited Away
# 7761   19404                    Dilwale Dulhania Le Jayenge
# 4138     680                                   Pulp Fiction
#
#                                                overview  popularity  \
# 6249  High schoolers Mitsuha and Taki are complete s...     167.115
# 7231  A young girl, Chihiro, becomes trapped in a st...      99.810
# 3312  The film centers on the love relationship amon...     131.827
# ...

# %%
df.isna().sum()
# Out:
# id                   0
# title                0
# overview             0
# popularity           0
# original_language    0
# vote_average         0
# dtype: int64

# %%
df.describe()
# Out:
#                  id   popularity  vote_average
# count    8560.00000  8560.000000   8560.000000
# mean   248721.70000    72.744300      8.570000
# std    301298.24703    49.667771      0.090005
# min       122.00000    11.514000      8.500000
# 25%       268.50000    28.515250      8.500000
# 50%     10042.00000    65.769500      8.500000
# 75%    530340.25000   100.653750      8.600000
# max    761053.00000   188.137000      8.800000

# %%
df.corr()
# Out:
#                     id  popularity  vote_average
# id            1.000000   -0.197395      0.171560
# popularity   -0.197395    1.000000     -0.478779
# vote_average  0.171560   -0.478779      1.000000

# %%
df.to_csv('moviesdata_csv')
